# %% [markdown]
# # Renumber Ligand Atoms' Residue Numbers
#
# ## Purpose
# See how BioPandas can be used to renumber residue numbers for ligand atoms.
#
# ## Methodology
# Quickly describe assumptions and processing steps.
#
# ## WIP - improvements
# Use this section only if the notebook is not final.
#
# Notable TODOs:
# - todo 1;
# - todo 2;
# - todo 3.
#
# ## Results
# Describe and comment the most important results.
#
# ## Suggested next steps
# State suggested next steps, based on results obtained in this notebook.

# %% [markdown]
# # Setup
#
# ## Library import
# We import all the required Python libraries

# %%
# Data manipulation
import pandas as pd
import numpy as np
from biopandas.pdb import PandasPdb

# Options for pandas
pd.options.display.max_columns = 50
pd.options.display.max_rows = 30

# Autoreload extension
if 'autoreload' not in get_ipython().extension_manager.loaded:
    # %load_ext autoreload
    
# %autoreload 2

# %% [markdown]
# ## Local library import
# We import all the required local libraries libraries

# %%
import os
if os.path.basename(os.getcwd()) == "notebooks" or os.path.basename(os.getcwd()) == "notebook":
    os.chdir('..')
    os.getcwd()

# %%
# Include local library paths
import sys
# sys.path.append('path/to/local/lib') # uncomment and fill to import local libraries

# Import local libraries

# %% [markdown]
# # Parameter definition
# We set all relevant parameters for our notebook. By convention, parameters are uppercase, while all the
# other variables follow Python's guidelines.

# %%
PDB_FILEPATH = "pdb/external/1g6n.1.pdb"

# %% [markdown]
# # Data import
# We retrieve all the required data for the analysis.

# %%
protein_pdb = PandasPdb().read_pdb(PDB_FILEPATH)

# %% [markdown]
# # Data processing
# Put here the core of the notebook. Feel free to further split this section into subsections.

# %%
ligand_pdb = protein_pdb.df['HETATM']
# Rename atom name
ligand_pdb['atom_name'] = "LIG"
# Renumber residue numbers
ligand_pdb['residue_number'] = ligand_pdb['residue_number'] + np.arange(ligand_pdb['residue_number'].shape[0])

# %%
protein_pdb.df['HETATM']
# Out:
#    record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0       HETATM         3173               LIG                  CMP
# 1       HETATM         3174               LIG                  CMP
# 2       HETATM         3175               LIG                  CMP
# 3       HETATM         3176               LIG                  CMP
# 4       HETATM         3177               LIG                  CMP
# 5       HETATM         3178               LIG                  CMP
# 6       HETATM         3179               LIG                  CMP
# 7       HETATM         3180               LIG                  CMP
# 8       HETATM         3181               LIG                  CMP
# 9       HETATM         3182               LIG                  CMP
# 10      HETATM         3183               LIG                  CMP
# 11      HETATM         3184               LIG                  CMP
# 12      HETATM         3185               LIG                  CMP
# 13      HETATM         3186               LIG                  CMP
# 14      HETATM         3187               LIG                  CMP
# 15      HETATM         3188               LIG                  CMP
# 16      HETATM         3189               LIG                  CMP
# 17      HETATM         3190               LIG                  CMP
# 18      HETATM         3191               LIG                  CMP
# 19      HETATM         3192               LIG                  CMP
# 20      HETATM         3193               LIG                  CMP
# 21      HETATM         3194               LIG                  CMP
#
#    chain_id  residue_number insertion blank_3  x_coord  y_coord  z_coord  \
# 0         A             621                     40.558   42.062   52.021
# 1         A             623                     40.284   41.032   50.963
# 2         A             625                     40.660   41.690   53.413
# 3         A             627                     41.852   42.872   51.531
# 4         A             629                     41.764   43.600   50.298
# 5         A             631                     40.695   44.641   50.513
# 6         A             633                     40.334   45.393   49.361
# 7         A             635                     39.400   43.962   50.721
# 8         A             637                     39.511   43.314   52.032
# 9         A             639                     38.310   45.089   50.723
# 10        A             641                     38.656   45.873   51.852
# 11        A             643                     38.942   45.850   49.462
# 12        A             645                     38.342   45.440   48.176
# 13        A             647                     38.449   44.244   47.461
# 14        A             649                     37.676   44.195   46.409
# 15        A             651                     37.010   45.389   46.411
# 16        A             653                     36.103   45.935   45.495
# 17        A             655                     35.550   45.319   44.445
# 18        A             657                     35.708   47.194   45.819
# 19        A             659                     36.173   47.844   46.863
# 20        A             661                     37.039   47.441   47.761
# 21        A             663                     37.403   46.175   47.466
#
#     occupancy  b_factor blank_4 segment_id element_symbol  charge  line_idx
# 0         1.0     16.49                                 P     NaN      3158
# 1         1.0     13.87                                 O     NaN      3159
# 2         1.0     16.14                                 O     NaN      3160
# 3         1.0     15.03                                 O     NaN      3161
# 4         1.0     13.39                                 C     NaN      3162
# 5         1.0     14.05                                 C     NaN      3163
# 6         1.0     13.84                                 O     NaN      3164
# 7         1.0     13.89                                 C     NaN      3165
# 8         1.0     14.80                                 O     NaN      3166
# 9         1.0     13.90                                 C     NaN      3167
# 10        1.0     13.08                                 O     NaN      3168
# 11        1.0     13.70                                 C     NaN      3169
# 12        1.0     12.36                                 N     NaN      3170
# 13        1.0     11.75                                 C     NaN      3171
# 14        1.0     11.87                                 N     NaN      3172
# 15        1.0     11.28                                 C     NaN      3173
# 16        1.0     12.41                                 C     NaN      3174
# 17        1.0     10.72                                 N     NaN      3175
# 18        1.0     11.55                                 N     NaN      3176
# 19        1.0     11.15                                 C     NaN      3177
# 20        1.0     11.90                                 N     NaN      3178
# 21        1.0     12.31                                 C     NaN      3179

# %%
# Inter-connect ligand atoms in -spcust format
from itertools import combinations
ligand_residues = [tuple(item) for item in np.vstack((ligand_pdb['residue_number'], ligand_pdb['chain_id'])).T]
ligand_springs = list(combinations(ligand_residues, 2))

# %%
ligand_springs[:5]
# Out:
# [((621, 'A'), (623, 'A')),
#  ((621, 'A'), (625, 'A')),
#  ((621, 'A'), (627, 'A')),
#  ((621, 'A'), (629, 'A')),
#  ((621, 'A'), (631, 'A'))]

# %%
# Write ligand-protein (amino acid  and ligand atoms) interactions 
protein_ligand_springs =[((71, 'A'), (631, 'A')),\
                         ((72, 'A'), (631, 'A')),\
                         ((82, 'A'), (623, 'A')),\
                         ((83, 'A'), (622, 'A')),\
                         ((127, 'A'), (638, 'A')),\
                         ((128, 'B'), (638, 'A'))]

# %%
# Write spfile for GENENMM's -spcust flag input
def write_spfile(data , output_dir="misc/"):
    """ Writes spfile from a list of tuples representing
        springs between two residues.
    """
    spfile_line_format = " {:4d} {:1s} {:4d} {:1s}\n"
    
    spfile_lines = []
    for line in data:
        residue_number_1 = line[0][0]
        chain_id_1 = line[0][1]
        residue_number_2 = line[1][0]
        chain_id_2 = line[1][1]

        spfile_line = spfile_line_format.format(residue_number_1, chain_id_1,\
                                                residue_number_2, chain_id_2)
        spfile_lines.append(spfile_line)
    
    spfile_output_filepath = os.path.join(output_dir, "fix.springs")  
    with open(spfile_output_filepath, 'w') as spfile:
        spfile.writelines(spfile_lines)
        
    return None

spring_data = ligand_springs + protein_ligand_springs
write_spfile(spring_data)

# %% [markdown]
# # References
# We report here relevant references:
# 1. author1, article1, journal1, year1, url1
# 2. author2, article2, journal2, year2, url2
